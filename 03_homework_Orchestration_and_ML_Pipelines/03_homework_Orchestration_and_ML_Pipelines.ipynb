# %% [markdown]
# ## Pavan's Homework

# %%
#03_homework_Orchestration_and_ML_Pipelines.ipynb

# %% [markdown]
# ## Question 1. Run Mage First, let's run Mage with Docker Compose. Follow the quick start guideline.
#
# What's the version of Mage we run?
#
# (You can see it in the UI)

# %% [markdown]
# ## Answer 1: v0.9.73  ![image.png](attachment:image.png)

# %% [markdown]
# ## Question 2. Creating a project Now let's create a new project. We can call it "homework_03", for example.
#
# How many lines are in the created metadata.yaml file?
#
# 35
# 45
# 55
# 65

# %% [markdown]
# ## Pavan’s Answer : 55   ![image.png](attachment:image.png)

# %% [markdown]
# ## Question 3. Creating a pipeline Let's create an ingestion code block.
#
# In this block, we will read the March 2023 Yellow taxi trips data.
#
# How many records did we load?
#
# 3,003,766
#
# 3,203,766
#
# 3,403,766
#
# 3,603,766

# %% [markdown]
# ## Pavan's Answer:   3403766      ![image.png](attachment:image.png)

# %% [markdown]
# ## Question 4. Data preparation Let's adjust it and apply to the data we loaded in question 3.
#
# What's the size of the result?
#
# 2,903,766
#
# 3,103,766
#
# 3,316,216
#
# 3,503,766

# %% [markdown]
# ## Pavan's Answer: 3,316,216      ![image.png](attachment:image.png)

# %% [markdown]
# ## Question 5. What's the intercept of the model?
#
# Hint: print the intercept_ field in the code block
#
# 21.77
#
# 24.77
#
# 27.77
#
# 31.77

# %% [markdown]
# ## Pavan's Answer:  24.77    ![image.png](attachment:7b558830-e958-4d7e-8588-0699c7e3711d.png)

# %% [markdown]
# ## Question 6. Find the logged model, and find MLModel file. What's the size of the model? (model_size_bytes field):
#
# 14,534
#
# 9,534
#
# 4,534
#
# 1,534

# %% [markdown]
# ## Pavan's Answer : 4,534  ![image.png](attachment:1eb31006-da08-45ae-a5b5-7614ac0bab5f.png)
